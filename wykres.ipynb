# %%
# %load_ext autoreload
# %autoreload 2


from osm_parser import OSMParser


parser = OSMParser("map.osm")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 8
#       2 get_ipython().run_line_magic('autoreload', '2')
#       5 from osm_parser import OSMParser
# ----> 8 parser = OSMParser("map.osm")
#
# File ~/Documents/school/cycly/osm_parser.py:10, in OSMParser.__init__(self, filename)
#       7 self.root = ET.parse(filename).getroot()
#       9 # wczytanie wszystkiego
# ---> 10 self.ways: list[Way] = read_model(Way, self.root)
#      11 self.nodes: list[Node] = read_model(Node, self.root)
#      12 self.relations: list[Relation] = read_model(Relation, self.root)
#
# File ~/Documents/school/cycly/models.py:14, in read_model(model, parent)
#      13 def read_model(model: Type, parent: ET.Element) -> Type:
# ---> 14     return [model.parsed(item) for item in parent.findall(model.selector)]
#
# File ~/Documents/school/cycly/models.py:14, in <listcomp>(.0)
#      13 def read_model(model: Type, parent: ET.Element) -> Type:
# ---> 14     return [model.parsed(item) for item in parent.findall(model.selector)]
#
# File ~/Documents/school/cycly/models.py:79, in Way.parsed(item)
#      74 @staticmethod
#      75 def parsed(item):
#      76     return Way(
#      77         int(item.attrib["id"]),
#      78         item.attrib["visible"] == "true",
# ---> 79         read_model(Nd.selector, item),
#      80     )
#
# File ~/Documents/school/cycly/models.py:14, in read_model(model, parent)
#      13 def read_model(model: Type, parent: ET.Element) -> Type:
# ---> 14     return [model.parsed(item) for item in parent.findall(model.selector)]
#
# AttributeError: 'str' object has no attribute 'selector'

# %%
import matplotlib.pyplot as plt

way = [x for x in parser.ways if x.id == 4576735][0]
lat = [x.lat for x in way.nodes]
lon = [ x.lon for x in way.nodes]

bounds = parser.get_bounds()

plt.plot(lon, lat, marker='o', linestyle='-')

# Add labels and title
plt.xlabel("Longitude")

plt.ylabel("Latitude")
plt.title("Standard Line Plot")

plt.ylim(bounds.min_lat, bounds.max_lat)
plt.xlim(bounds.min_lon, bounds.max_lon)
# Display the plot
plt.grid()
plt.show()

# %%
samples = parser.relations[0:100]

# %%
print(parser.get_relation(8367581))
print(parser.get_relation(8493861).tags)
# Out:
# Relation(id=8367581, visible=True, members=[Member(type='way', ref=4587568, role='from'), Member(type='node', ref=2016244055, role='via'), Member(type='way', ref=4587568, role='to')], nodes=[Node(id=2016244055, visible=True, lat=50.2824029, lon=18.6835273, tags=[])], ways=[Way(id=4587568, visible=True, nds=[Nd(ref=2016244055), Nd(ref=5677536404), Nd(ref=3580994635), Nd(ref=1493286015), Nd(ref=2016244172), Nd(ref=2016244083), Nd(ref=628198127), Nd(ref=2016244102), Nd(ref=6584124202), Nd(ref=11031816704), Nd(ref=11031816703), Nd(ref=2016244089), Nd(ref=476797327), Nd(ref=29014932), Nd(ref=628198121), Nd(ref=628198119), Nd(ref=6673377047), Nd(ref=6673377052), Nd(ref=3733605993), Nd(ref=628198112), Nd(ref=6673377055), Nd(ref=628198111), Nd(ref=29014930), Nd(ref=3217900541), Nd(ref=3217900536), Nd(ref=29014928), Nd(ref=3217900529), Nd(ref=3217900528), Nd(ref=29014927), Nd(ref=3024988101), Nd(ref=28901813)], tags=[], nodes=[]), Way(id=4587568, visible=True, nds=[Nd(ref=2016244055), Nd(ref=5677536404), Nd(ref=3580994635), Nd(ref=1493286015), Nd(ref=2016244172), Nd(ref=2016244083), Nd(ref=628198127), Nd(ref=2016244102), Nd(ref=6584124202), Nd(ref=11031816704), Nd(ref=11031816703), Nd(ref=2016244089), Nd(ref=476797327), Nd(ref=29014932), Nd(ref=628198121), Nd(ref=628198119), Nd(ref=6673377047), Nd(ref=6673377052), Nd(ref=3733605993), Nd(ref=628198112), Nd(ref=6673377055), Nd(ref=628198111), Nd(ref=29014930), Nd(ref=3217900541), Nd(ref=3217900536), Nd(ref=29014928), Nd(ref=3217900529), Nd(ref=3217900528), Nd(ref=29014927), Nd(ref=3024988101), Nd(ref=28901813)], tags=[], nodes=[])])
# Relation(id=8493861, visible=True, members=[Member(type='node', ref=7997713370, role=''), Member(type='node', ref=7997713371, role=''), Member(type='node', ref=7997713372, role=''), Member(type='node', ref=7997713374, role=''), Member(type='node', ref=7997713375, role=''), Member(type='way', ref=183981866, role=''), Member(type='way', ref=942609500, role=''), Member(type='way', ref=384566130, role=''), Member(type='way', ref=687122223, role=''), Member(type='way', ref=550911124, role=''), Member(type='way', ref=560719227, role=''), Member(type='way', ref=854245234, role=''), Member(type='way', ref=475970059, role=''), Member(type='way', ref=687122214, role=''), Member(type='way', ref=156804036, role=''), Member(type='way', ref=687122213, role=''), Member(type='way', ref=550875360, role=''), Member(type='way', ref=550874658, role=''), Member(type='way', ref=550874656, role=''), Member(type='way', ref=892088485, role=''), Member(type='way', ref=892088484, role=''), Member(type='way', ref=30156359, role=''), Member(type='way', ref=613116231, role=''), Member(type='way', ref=24408458, role=''), Member(type='way', ref=973018667, role=''), Member(type='way', ref=105255365, role=''), Member(type='way', ref=692984184, role=''), Member(type='way', ref=692984187, role=''), Member(type='way', ref=310712775, role=''), Member(type='way', ref=24270164, role=''), Member(type='way', ref=341263680, role=''), Member(type='way', ref=147397622, role=''), Member(type='way', ref=387402206, role=''), Member(type='way', ref=807743595, role=''), Member(type='way', ref=47677698, role=''), Member(type='way', ref=389618278, role=''), Member(type='way', ref=854245238, role=''), Member(type='way', ref=389618279, role=''), Member(type='way', ref=854245239, role=''), Member(type='way', ref=389615276, role=''), Member(type='way', ref=854245242, role=''), Member(type='way', ref=237042838, role=''), Member(type='way', ref=854245243, role=''), Member(type='way', ref=236860813, role=''), Member(type='way', ref=207636336, role=''), Member(type='way', ref=4629450, role=''), Member(type='way', ref=207636344, role=''), Member(type='way', ref=87807805, role=''), Member(type='way', ref=258780250, role=''), Member(type='way', ref=240512176, role=''), Member(type='way', ref=240512845, role=''), Member(type='way', ref=854245245, role=''), Member(type='way', ref=287641920, role=''), Member(type='way', ref=1094426624, role=''), Member(type='way', ref=510848778, role=''), Member(type='way', ref=838291788, role=''), Member(type='way', ref=549343433, role=''), Member(type='way', ref=163996499, role=''), Member(type='way', ref=163996492, role=''), Member(type='way', ref=613116228, role=''), Member(type='way', ref=613116221, role=''), Member(type='way', ref=973104705, role=''), Member(type='way', ref=973104702, role=''), Member(type='way', ref=896453949, role=''), Member(type='way', ref=896453948, role=''), Member(type='way', ref=1009695200, role=''), Member(type='way', ref=613116224, role=''), Member(type='way', ref=415541129, role=''), Member(type='way', ref=415541130, role=''), Member(type='way', ref=377274628, role=''), Member(type='way', ref=499852461, role=''), Member(type='way', ref=344602430, role=''), Member(type='way', ref=364915430, role=''), Member(type='way', ref=1009695199, role=''), Member(type='way', ref=151385877, role=''), Member(type='way', ref=364915429, role=''), Member(type='way', ref=364915431, role=''), Member(type='way', ref=1011328168, role=''), Member(type='way', ref=35813424, role=''), Member(type='way', ref=39540295, role=''), Member(type='way', ref=35823569, role=''), Member(type='way', ref=35823568, role=''), Member(type='way', ref=444255850, role=''), Member(type='way', ref=613116226, role=''), Member(type='way', ref=973114784, role=''), Member(type='way', ref=974780737, role=''), Member(type='way', ref=1011328170, role=''), Member(type='way', ref=209364985, role=''), Member(type='way', ref=198312424, role=''), Member(type='way', ref=308567992, ro ...
# [autoreload of models failed: Traceback (most recent call last):
#   File "/Users/bartoszbugla/Documents/school/cycly/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/bartoszbugla/Documents/school/cycly/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/bartoszbugla/Documents/school/cycly/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/bartoszbugla/Documents/school/cycly/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bartoszbugla/Documents/school/cycly/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/bartoszbugla/Documents/school/cycly/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
